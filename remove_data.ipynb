# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('normal_cb.csv')
df
# Out:
#       Unnamed: 0                            fullPath                fileName  \
# 0              2   Benign\0029\C_0029_1.RIGHT_CC.jpg   C_0029_1.RIGHT_CC.jpg
# 1              3  Benign\0029\C_0029_1.RIGHT_MLO.jpg  C_0029_1.RIGHT_MLO.jpg
# 2              4    Benign\0033\C_0033_1.LEFT_CC.jpg    C_0033_1.LEFT_CC.jpg
# 3              5   Benign\0033\C_0033_1.LEFT_MLO.jpg   C_0033_1.LEFT_MLO.jpg
# 4              8    Benign\0217\C_0217_1.LEFT_CC.jpg    C_0217_1.LEFT_CC.jpg
# ...          ...                                 ...                     ...
# 2565        5389   Cancer\4192\D_4192_1.LEFT_MLO.jpg   D_4192_1.LEFT_MLO.jpg
# 2566        5394   Cancer\4193\D_4193_1.RIGHT_CC.jpg   D_4193_1.RIGHT_CC.jpg
# 2567        5395  Cancer\4193\D_4193_1.RIGHT_MLO.jpg  D_4193_1.RIGHT_MLO.jpg
# 2568        5396    Cancer\4199\D_4199_1.LEFT_CC.jpg    D_4199_1.LEFT_CC.jpg
# 2569        5397   Cancer\4199\D_4199_1.LEFT_MLO.jpg   D_4199_1.LEFT_MLO.jpg
#
# ...

# %%
file_name = df['fileName'].values
file_name
# Out:
# array(['C_0029_1.RIGHT_CC.jpg', 'C_0029_1.RIGHT_MLO.jpg',
#        'C_0033_1.LEFT_CC.jpg', ..., 'D_4193_1.RIGHT_MLO.jpg',
#        'D_4199_1.LEFT_CC.jpg', 'D_4199_1.LEFT_MLO.jpg'], dtype=object)

# %%
import os

# Đường dẫn của thư mục chứa các tệp bạn muốn xóa
folder_path = 'E:\data_ddsm\\data_ddsm_final_copy\mask'

# Lặp qua mỗi tệp trong thư mục
for filename in os.listdir(folder_path):
    # Kiểm tra xem tên tệp có trùng với danh sách tên tệp bạn muốn xóa hay không
    if filename in file_name:
        print(os.path.join(folder_path, filename))
        # Sử dụng hàm os.remove() để xóa tệp
        os.remove(os.path.join(folder_path, filename))
# Out:
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1123_1.RIGHT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1124_1.RIGHT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1124_1.RIGHT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1170_1.LEFT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1170_1.LEFT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1177_1.LEFT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1242_1.RIGHT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1242_1.RIGHT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1259_1.RIGHT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1259_1.RIGHT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1264_1.LEFT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1264_1.LEFT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1265_1.LEFT_CC.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1265_1.LEFT_MLO.jpg
# E:\data_ddsm\data_ddsm_final_copy\mask\A_1266_1.RIGHT_CC.jpg
# ...
